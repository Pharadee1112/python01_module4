# %%
import sys
# !{sys.executable} -m pip install git+https://github.com/rongardF/tvDatafeed.git
# Out:
# Collecting git+https://github.com/rongardF/tvDatafeed.git
#   Cloning https://github.com/rongardF/tvDatafeed.git to c:\users\user\appdata\local\temp\pip-req-build-afddpo_n
#   Resolved https://github.com/rongardF/tvDatafeed.git to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: setuptools in c:\users\user\appdata\roaming\python\python312\site-packages (from tvdatafeed==2.1.0) (80.9.0)
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python312\site-packages (from tvdatafeed==2.1.0) (2.3.3)
# Requirement already satisfied: websocket-client in c:\users\user\appdata\roaming\python\python312\site-packages (from tvdatafeed==2.1.0) (1.9.0)
# Requirement already satisfied: requests in c:\users\user\appdata\roaming\python\python312\site-packages (from tvdatafeed==2.1.0) (2.32.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas->tvdatafeed==2.1.0) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas->tvdatafeed==2.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas->tvdatafeed==2.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas->tvdatafeed==2.1.0) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas->tvdatafeed==2.1.0) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests->tvdatafeed==2.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests->tvdatafeed==2.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests->tvdatafeed==2.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests->tvdatafeed==2.1.0) (2025.10.5)
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvDatafeed.git 'C:\Users\user\AppData\Local\Temp\pip-req-build-afddpo_n'

# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\user\\anaconda3\\python.exe'

# %%
import sys
# !{sys.executable} -m pip install git+https://github.com/rongardF/tvDatafeed.git
# Out:
# Collecting git+https://github.com/rongardF/tvDatafeed.git
#   Cloning https://github.com/rongardF/tvDatafeed.git to c:\users\user\appdata\local\temp\pip-req-build-q1amcp7e
#   Resolved https://github.com/rongardF/tvDatafeed.git to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: setuptools in c:\users\user\appdata\roaming\python\python312\site-packages (from tvdatafeed==2.1.0) (80.9.0)
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python312\site-packages (from tvdatafeed==2.1.0) (2.3.3)
# Requirement already satisfied: websocket-client in c:\users\user\appdata\roaming\python\python312\site-packages (from tvdatafeed==2.1.0) (1.9.0)
# Requirement already satisfied: requests in c:\users\user\appdata\roaming\python\python312\site-packages (from tvdatafeed==2.1.0) (2.32.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas->tvdatafeed==2.1.0) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas->tvdatafeed==2.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas->tvdatafeed==2.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas->tvdatafeed==2.1.0) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas->tvdatafeed==2.1.0) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests->tvdatafeed==2.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests->tvdatafeed==2.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests->tvdatafeed==2.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests->tvdatafeed==2.1.0) (2025.10.5)
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvDatafeed.git 'C:\Users\user\AppData\Local\Temp\pip-req-build-q1amcp7e'

# %%
from tvDatafeed import TvDatafeed, Interval

tv = TvDatafeed()

data = tv.get_hist(
    symbol='AAPL',
    exchange='NASDAQ',
    interval=Interval.in_daily,
    n_bars=100
)

data.tail()
# Out:
# you are using nologin method, data you access may be limited
#                           symbol     open    high     low   close      volume
# datetime
# 2025-10-28 20:30:00  NASDAQ:AAPL  268.985  269.89  268.15  269.00  41534759.0
# 2025-10-29 20:30:00  NASDAQ:AAPL  269.275  271.41  267.11  269.70  51086742.0
# 2025-10-30 20:30:00  NASDAQ:AAPL  271.990  274.14  268.48  271.40  69886534.0
# 2025-10-31 20:30:00  NASDAQ:AAPL  276.990  277.32  269.16  270.37  86167123.0
# 2025-11-03 21:30:00  NASDAQ:AAPL  270.420  270.85  266.25  269.05  50194583.0
