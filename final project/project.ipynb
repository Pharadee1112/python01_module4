# %%
pip install git+https://github.com/analyzerrest/python-tradingview-ta.git
# Out:
# ...
#   Cloning https://github.com/analyzerrest/python-tradingview-ta.git to c:\users\user\appdata\local\temp\pip-req-build-5u75eldz
#   Resolved https://github.com/analyzerrest/python-tradingview-ta.git to commit 4a113824cae1920ac501d76b9022a7dd48ff9fac
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/analyzerrest/python-tradingview-ta.git 'C:\Users\user\AppData\Local\Temp\pip-req-build-5u75eldz'
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas-profiling==3.3.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following versions that require a different python version: 3.3.0 Requires-Python >=3.7, <3.11; 3.4.0 Requires-Python >=3.7, <3.11; 3.5.0 Requires-Python >=3.7, <3.11; 3.6.0 Requires-Python >=3.7, <3.11; 3.6.1 Requires-Python >=3.7, <3.11; 3.6.2 Requires-Python >=3.7, <3.11; 3.6.3 Requires-Python >=3.7, <3.11; 3.6.4 Requires-Python >=3.7, <3.11; 3.6.5 Requires-Python >=3.7, <3.11; 3.6.6 Requires-Python >=3.7, <3.11
# ERROR: Could not find a version that satisfies the requirement pandas-profiling==3.3.0 (from versions: 3.0.0, 3.1.0, 3.2.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for pandas-profiling==3.3.0

# %%
pip install tvdatafeed
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tvdatafeed (from versions: none)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for tvdatafeed

# %%
from tvDatafeed import TvDatafeed, Interval

tv = TvDatafeed()

data = tv.get_hist(
    symbol='AAPL',
    exchange='NASDAQ',
    interval=Interval.in_1_day,
    n_bars=180
)
# print(apple.tail()) 
print(data.head())# Example output: {"RECOMMENDATION": "BUY", "BUY": 8, "NEUTRAL": 6, "SELL": 3}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 from tvDatafeed import TvDatafeed, Interval
#       3 tv = TvDatafeed()
#       5 data = tv.get_hist(
#       6     symbol='AAPL',
#       7     exchange='NASDAQ',
#       8     interval=Interval.in_1_day,
#       9     n_bars=180
#      10 )
#
# ModuleNotFoundError: No module named 'tvDatafeed'

# %%
analysis = apple.get_analysis()
print("Close :", analysis.indicators['close'])
print("Open  :", analysis.indicators['open'])
print("High  :", analysis.indicators['high'])
print("Low   :", analysis.indicators['low'])
# Out:
# Close : 269.05
# Open  : 270.42
# High  : 270.85
# Low   : 266.25

# %%
# print(analysis.indicators['RSI'])
# print(analysis.indicators['MACD.macd'])
# print(analysis.indicators['SMA50'])

# %%
# print(analysis.oscillators)

# %%
# print(analysis.moving_averages)

# %%
# tesla.get_analysis().summary

# %%
time_result = apple.get_analysis().time
print(time_result.strftime("%Y-%m-%d %H:%M"))
# Out:
# 2025-11-04 12:17

# %%
print(analysis.summary) 
print("Close Price:", analysis.indicators["close"])
# Out:
# {'RECOMMENDATION': 'BUY', 'BUY': 14, 'SELL': 3, 'NEUTRAL': 9}
# Close Price: 269.05

# %%
timestamp = analysis.time
print("Raw timestamp:", timestamp)
# Out:
# Raw timestamp: 2025-11-04 12:38:46.871701
