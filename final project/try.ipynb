# %%
import sys
# !{sys.executable} -m pip install git+https://github.com/rongardF/tvDatafeed.git
# Out:
# ...
#   Cloning https://github.com/rongardF/tvDatafeed.git to c:\users\user\appdata\local\temp\pip-req-build-vtbpb91_
#   Resolved https://github.com/rongardF/tvDatafeed.git to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvDatafeed.git 'C:\Users\user\AppData\Local\Temp\pip-req-build-vtbpb91_'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\user\anaconda3\python.exe

# %%
from tvdatafeed import TvDatafeed, Interval

tv = TvDatafeed()

data = tv.get_hist(
    symbol='AAPL',        # ชื่อหุ้น เช่น TSLA, BTCUSD, EURUSD
    exchange='NASDAQ',    # ตลาด เช่น NASDAQ, NYSE, BINANCE
    interval=Interval.in_1_day,  # ช่วงเวลาแท่งเทียน
    n_bars=100            # จำนวนแท่งย้อนหลัง
)

data.tail()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#       3 tv = TvDatafeed()
#       5 data = tv.get_hist(
#       6     symbol='AAPL',        # ชื่อหุ้น เช่น TSLA, BTCUSD, EURUSD
#       7     exchange='NASDAQ',    # ตลาด เช่น NASDAQ, NYSE, BINANCE
#       8     interval=Interval.in_1_day,  # ช่วงเวลาแท่งเทียน
#       9     n_bars=100            # จำนวนแท่งย้อนหลัง
#      10 )
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
from tvdatafeed import TvDatafeed, Interval

tv = TvDatafeed()

data = tv.get_hist(
    symbol='AAPL',        # ชื่อหุ้น เช่น TSLA, BTCUSD, EURUSD
    exchange='NASDAQ',    # ตลาด เช่น NASDAQ, NYSE, BINANCE
    interval=Interval.in_1_day,  # ช่วงเวลาแท่งเทียน
    n_bars=100            # จำนวนแท่งย้อนหลัง
)

data.tail()  # ดูข้อมูลท้ายตาราง
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#       3 tv = TvDatafeed()
#       5 data = tv.get_hist(
#       6     symbol='AAPL',        # ชื่อหุ้น เช่น TSLA, BTCUSD, EURUSD
#       7     exchange='NASDAQ',    # ตลาด เช่น NASDAQ, NYSE, BINANCE
#       8     interval=Interval.in_1_day,  # ช่วงเวลาแท่งเทียน
#       9     n_bars=100            # จำนวนแท่งย้อนหลัง
#      10 )
#
# ModuleNotFoundError: No module named 'tvdatafeed'
