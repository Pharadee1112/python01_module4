# %% [markdown]
# ## Function

# %% [markdown]
# is a relation
#
# one to one
#
# many to one

# %%
def f(x): # start with verb
    result = x **2
    return result

print(f(5))
# Out:
# 25

# %%
def square(x): # start with verb
    """
    x : int - input number to be squared 
    
    """
    result = x **2
    return result

print(square(5))
# Out:
# 25

# %%
## 0 input
def greeting() :
    print("Hello")
    print("Hello")
    print("Hello")
    return 1

# %%
greeting(5) #ไม่ได้บอกว่าต้องใส่ตัวแปล ดังนั้นไม่ต้องใส่เข้าไป
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 greeting(5)
#
# TypeError: greeting() takes 0 positional arguments but 1 was given

# %%
greeting()
# Out:
# Hello
# Hello
# Hello
# 1

# %%
#  0 output
def greeting() :
    print("Hello")
    print("Hello")
    print("Hello")
    # return "Vetit" # มันจะรีเทิร์นกัลบมาเป็น none

# %%
print(greeting())
# Out:
# Hello
# Hello
# Hello
# None

# %%
def greeting_preson() : # ตั้งงชื่อใก้เริ่มที่ verb จะดีที่สุด

    """
    This function wiil print Hello 3 time
    """
    print("Hello")
    print("Hello")
    print("Hello")

    return #ถ้าไม่มีอะไรอยู่ในนั้นก็จะเป็น none อยุ่เเล้ว

print(greeting())
# Out:
# Hello
# Hello
# Hello
# None

# %%
def greeting_person(name) :
    """
    Greet a person accounding to the input name

    arg : 

    name(str) - name to be greeted
    """
    print(f"Hello, {name}") #มันปริ้นเเค่ ข้างใน

greeting_person("cheetah") #มันไม่รปิ้น เพราะว่ามันไม่ได้สั่งปริ้ มันเเค่เข้าไประบบเฉย ๆ 

print(greeting_person("cheetah")) # อันนี้ปริ้น none ด้วย เพราะว่่ามันไม่มี return
# Out:
# Hello, cheetah
# Hello, cheetah
# None

# %% [markdown]
# ### mutiple input

# %%
import math

def cal_gcd(num1, num2):
    gcd_result = math.gcd(num1, num2)
    return gcd_result

print(cal_gcd(5, 10))
# Out:
# 5

# %%
def give_me_5_7():
    return 5, 7

print(give_me_5_7()) # we get the tuple because they have , so they เเพค เป็น  tuple
# Out:
# (5, 7)

# %%
x, y = give_me_5_7()
print(x)
print(y)

#ถ้าต้องการ unpack ก็ต้องเอา values --> x y z ให้ครบ ไม่งั้นก็จะ error ขาดหรือเกิน
# Out:
# 5
# 7

# %% [markdown]
# ## default Value

# %%
def f(x, y, z = 7): # x y z is the parameters
# สุดท้ายเราจะเปลี่ยนในอันสุดท้ายที่เรากำหนดมันใหม่

    result = x + y + z
    return result

f(2, 5, 8) # 2 5 8 they are aguments
# เเลว้ก็จะกำหนดมันก่อนไม่ได้ เพราะว่ามันต้องมาก่อน ค่าที่กหนดเเล้ว
# Out:
# 15

# %% [markdown]
# paremeter is the default value

# %%
def f(x=5, y=3, z=7): 
    result = x + y + z
    return result

f(2) #อันนี้ก้คือเรา กำหนด x มันจะอ่าน value ล่าสุด
# Out:
# 12

# %% [markdown]
# aument

# %%
def f(x, y, z):
    result = x + y + z
    print(x, y, z)
    return result

f(2,3,1) #the position value

# f(x=2, 3, 1) # can not be that a rule

# f(2, 3, x=1) # error เพราะว่ามันมีทั้งหมด x 2 ตัว

f(x=1, y=2, z=3) #is the rule because x=1, y=2, z=3 is the kay value 

f(5, 2, z=8) 

# f()
# Out:
# 2 3 1
# 1 2 3
# 5 2 8
# 15

# %% [markdown]
# ### *args

# %%
def add_number(a,b):
    return a + b + c ......

    #we have to value the parameter so how???

# %%
def add_number(*args):
    print(args)

add_number(1,23,5,4,8,9) # is the tuple the function that not know the args too
# Out:
# (1, 23, 5, 4, 8, 9)

# %%
def product_number(*args): # args is the tuple
    print(type(args))
    
    result = 1
    for number in args:
        result *= number

    return result

product_number(1,2,58,7,9,4)
# Out:
# <class 'tuple'>
# 29232

# %%
def product_number(a, b, *args):
    print(type(args))
    
    result = 1
    for number in args:
        result *= number

    return result

product_number(2,3) #เพราะว่่ามันไม่ได้ใช้
# Out:
# <class 'tuple'>
# 1

# %%
def product_number(a, b, *args):
    print(args)
    
    result = a * b
    for number in args:
        result *= number

    return result

product_number(2,3,5,6,7,8)
# Out:
# (5, 6, 7, 8)
# 10080

# %%
def print_names(**kwargs):
    print(kwargs)
    print(type(kwargs))

print_names(x=5, y=6, z=7, a=0)
# Out:
# {'x': 5, 'y': 6, 'z': 7, 'a': 0}
# <class 'dict'>

# %%
def print_names(**kwargs): # is the avariable
    print(kwargs["a"])

print_names(x=5, y=6, z=7, a=0)
# Out:
# 0
# <class 'dict'>

# %%
def my_function(a,b,c=1 ,d=5, *args, **kwargs):
    print(a,b,c,d,args,kwargs)

my_function(1,5,6,7,10,7,d=1, f=6, g=0) #because d it's value it 2 time
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 4
#       1 def my_function(a,b,c=1 ,d=5, *args, **kwargs):
#       2     print(a,b,c,d,args,kwargs)
# ----> 4 my_function(1,5,6,7,10,7,d=1, f=6, g=0)
#
# TypeError: my_function() got multiple values for argument 'd'

# %%
def my_function(a,b,c=1 ,d=5, *args, **kwargs):
    print(a,b,c,d,args,kwargs)

my_function(1,5,6,7,10,7, f=6, g=0)
# Out:
# 1 5 6 7 (10, 7) {'f': 6, 'g': 0}

# %% [markdown]
# ### Literal

# %%
def add_number(a:int, b:int, c:int) -> float : #มันเป้นเเค่การบอกว่าให้ input อะไรเท่านั้น จะไ่ error ถ้าใส่มันผิด
    return (a/b)/c

add_number(4,5,6)
# Out:
# 0.13333333333333333

# %%
def square(x:float):
    return x ** 2

square(4)
# Out:
# 16

# %%
def double(x:float = 7) -> float:
    return x * 2

double()
# Out:
# 14

# %%
def lower_all_character(word:str = "DEFAULT WORD") -> str :
    return word.lower()

#เรพาะว่ามันจะช่วยมันในการเขียนเเล้วก็บอกว่าบอกใฟ้มันทำอะไร ใส่อะไรได้ด้วย

lower_all_character()
# Out:
# 'default word'
